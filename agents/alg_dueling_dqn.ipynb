# %% [markdown]
# ## Dueling Deep Q-Network (Dueling DQN)
#
# El Dueling DQN modifica la **arquitectura** de la red neuronal, sin cambiar el algoritmo de entrenamiento. A diferencia del Double DQN, que modifica el **cálculo del target** de Bellman, aquí la innovación es puramente arquitectónica.
#
# En lugar de estimar Q(s,a) directamente, la red lo descompone en dos partes:
#
# - **Función de valor** $V(s)$: cuánta recompensa total esperamos desde el estado $s$, independientemente de la acción
# - **Función de ventaja** $A(s,a)$: cuánto mejor es la acción $a$ respecto a las demás en el estado $s$
#
# Se combinan para obtener los Q-values:
#
# $$Q(s,a) = V(s) + \left( A(s,a) - \frac{1}{|\mathcal{A}|} \sum_{a'} A(s,a') \right)$$
#
# La resta de la media de ventajas estabiliza el entrenamiento evitando que $V$ y $A$ sean ambiguas. Esta descomposición es especialmente útil cuando muchas acciones tienen valores Q similares — la red puede aprender $V(s)$ con precisión sin necesidad de visitar cada par $(s,a)$ individualmente.
#
# El resto del algoritmo (replay buffer, política epsilon-greedy, descenso del gradiente) es idéntico al DQN estándar.

# %% [markdown]
# ## Transition y Memory (Replay Buffer)

# %%
import random
from collections import deque
from typing import Any, List, NamedTuple, Sequence, SupportsFloat, Union


class Transition(NamedTuple):
    """Representa la transición de un estado al siguiente."""
    prev_state: Any
    next_state: Any
    action: Any
    reward: SupportsFloat
    terminated: bool


class Memory:
    """Búfer de reproducción (replay buffer) de tamaño fijo, lo usamos para que el agente no entrene con experiencias en orden cronológico
    que introducirían correlaciones que desestabilizarian el entrenamiento"""

    def __init__(self, size: int):
        self.max_size = int(size)
        self.transitions: deque = deque(maxlen=self.max_size) #inicializamos una cola con el tamaño máximo fijo

    def remember(self, transition: Transition):
        self.transitions.append(transition) # guardamos una transición

    def batch(self, n: int) -> List[Transition]:
        n = min(len(self.transitions), n)
        return random.sample(self.transitions, n) #extrae una muestra aleatoria de n transiciones

    def __len__(self) -> int:
        return len(self.transitions) # lo usamos para comprobar si el batch tiene n transiciones

    def __getitem__(self, key: Union[int, slice]) -> Union[Transition, Sequence[Transition]]:
        return self.transitions.__getitem__(key) # para acceder al buffer ya sea a una sola transicion o a un conjunto de ellas.

# %% [markdown]
# ## Dueling DQN Agent
#
# La única diferencia respecto al DQN estándar está en la red neuronal: en lugar de
# una cabeza única que produce Q-values, tiene **dos cabezas** que producen $V(s)$ y
# $A(s,a)$ por separado y luego las combina. Esto permite que la red aprenda cuándo
# un estado es valioso independientemente de la acción, lo que acelera la convergencia
# especialmente en estados donde las acciones tienen efectos similares.

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim


class DuelingQNetwork(nn.Module):
    """Red neuronal con arquitectura Dueling.
    Tronco compartido -> dos cabezas: V(s) y A(s,a) -> Q(s,a)
    """

    def __init__(self, n_obs, n_actions):
        super().__init__()

        # Tronco compartido
        self.trunk = nn.Sequential(
            nn.Linear(n_obs, 64),
            nn.ReLU(),
            nn.Linear(64, 64),
            nn.ReLU(),
        )

        # Cabeza de valor: V(s) -> escalar
        self.value_head = nn.Linear(64, 1)

        # Cabeza de ventaja: A(s,a) -> un valor por acción
        self.advantage_head = nn.Linear(64, n_actions)

    def forward(self, x):
        features = self.trunk(x)
        V = self.value_head(features)                  # (batch, 1)
        A = self.advantage_head(features)              # (batch, n_actions)
        # Restamos la media y no el máximo para mantener gradientes más suaves
        # y evitar que A colapse a cero en la acción óptima
        Q = V + (A - A.mean(dim=1, keepdim=True))
        return Q


class DuelingDQNAgent:
    """
    Agente Dueling Deep Q-Learning.
    Idéntico al DQN estándar salvo por el uso de DuelingQNetwork,
    que descompone Q(s,a) en V(s) + A(s,a).
    """

    def __init__(
        self,
        n_obs,
        n_actions,
        gamma,
        lr,
        batch_size,
        memory_size,
        epsilon,
        epsilon_min,
        epsilon_decay,
    ):
        self.n_actions = n_actions
        self.gamma = gamma
        self.batch_size = batch_size

        self.epsilon = epsilon
        self.epsilon_min = epsilon_min
        self.epsilon_decay = epsilon_decay

        self.memory = Memory(size=memory_size)

        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        self.model = DuelingQNetwork(n_obs, n_actions).to(self.device)
        self.optimizer = optim.Adam(self.model.parameters(), lr=lr)
        self.loss_fn = nn.MSELoss()

    def select_action(self, state):
        """Política epsilon-greedy."""
        if random.random() < self.epsilon:
            return random.randrange(self.n_actions)

        state_t = torch.FloatTensor(state).unsqueeze(0).to(self.device)
        with torch.no_grad():
            q_values = self.model(state_t)
        return int(q_values.argmax().item())

    def learn(self):
        """Un paso de entrenamiento: muestrea un batch y minimiza el MSE de Bellman.
        Igual que DQN estándar; la arquitectura Dueling ya produce los Q-values correctos.
        """
        if len(self.memory) < self.batch_size:
            return

        batch = self.memory.batch(self.batch_size)

        prev_states = torch.FloatTensor(np.array([t.prev_state for t in batch])).to(self.device)
        next_states = torch.FloatTensor(np.array([t.next_state for t in batch])).to(self.device)
        actions    = torch.LongTensor([t.action for t in batch]).to(self.device)
        rewards    = torch.FloatTensor([t.reward for t in batch]).to(self.device)
        terminated = torch.BoolTensor([t.terminated for t in batch]).to(self.device)

        # Q(s, a) para las acciones tomadas
        qs = self.model(prev_states).gather(1, actions.unsqueeze(1)).squeeze(1)

        # Valor objetivo: r + gamma * max_a' Q(s', a')  (0 si terminal)
        with torch.no_grad():
            next_qs = self.model(next_states).max(1).values
            next_qs[terminated] = 0.0
            targets = rewards + self.gamma * next_qs

        loss = self.loss_fn(qs, targets)
        self.optimizer.zero_grad()
        loss.backward()
        nn.utils.clip_grad_norm_(self.model.parameters(), 10.0) #limitimos la norma del gradiente a 10 para evitar cambios grandes que desestabilicen
        self.optimizer.step()

    def decay_epsilon(self):
        """Reduce epsilon para pasar poco a poco de explorar a explotar."""
        self.epsilon = max(self.epsilon_min, self.epsilon * self.epsilon_decay)

    def save(self, path):
        """Guarda los pesos de la red."""
        torch.save(self.model.state_dict(), path)

    def load(self, path):
        """Carga los pesos de la red."""
        self.model.load_state_dict(torch.load(path, map_location=self.device))
        self.model.eval()

# %% [markdown]
# ## Entrenamiento Dueling DQN
#
# El bucle de entrenamiento es idéntico al DQN estándar. La mejora está completamente encapsulada en la arquitectura de la red.

# %%
import os
import sys
import pandas as pd
from tqdm import tqdm

sys.path.append(os.path.abspath(".."))
from envs.continuous_parking_env import ContinuousParkingEnv
from IPython.display import clear_output

def train_dueling_dqn(
    episodes=2000,
    max_steps=300,
    warmup_steps=1000,
    gamma=0.95,
    lr=1e-3,
    batch_size=64,
    memory_size=10_000,
    epsilon=1.0,
    epsilon_min=0.05,
    epsilon_decay=0.995,
):
    env = ContinuousParkingEnv(render_mode=None)

    agent = DuelingDQNAgent(
        n_obs=env.observation_space.shape[0],  # 18
        n_actions=env.action_space.n,           # 7
        gamma=gamma,
        lr=lr,
        batch_size=batch_size,
        memory_size=memory_size,
        epsilon=epsilon,
        epsilon_min=epsilon_min,
        epsilon_decay=epsilon_decay,
    )

    # --- Arranque en frío: poblar el búfer con acciones aleatorias ---
    obs, _ = env.reset()
    for _ in range(warmup_steps):
        action = env.action_space.sample()
        next_obs, reward, terminated, truncated, _ = env.step(action)
        agent.memory.remember(Transition(
            prev_state=obs,
            next_state=next_obs,
            action=action,
            reward=reward,
            terminated=terminated,
        ))
        obs = next_obs
        if terminated or truncated:
            obs, _ = env.reset()

    # --- Bucle principal de entrenamiento ---
    results = []

    for episode in tqdm(range(episodes), desc="Training DQN"):
        obs, info = env.reset()
        total_reward = 0.0
        success = False
        collision = False

        # Control de atasco
        last_x, last_y = info["x"], info["y"]   # coordenadas reales
        stuck_steps = 0

        for step in range(max_steps):
            action = agent.select_action(obs)
            next_obs, reward, terminated, truncated, info = env.step(action)
            done = terminated or truncated

            # Detectar atasco: si no se mueve más de 0.05 en x ni en y durante 20 steps con esto agilizamos el entrenamiento
            if abs(info["x"] - last_x) < 0.05 and abs(info["y"] - last_y) < 0.05:
                stuck_steps += 1
            else:
                stuck_steps = 0
                last_x, last_y = info["x"], info["y"]

            if stuck_steps >= 20:
                done = True

            agent.memory.remember(Transition(
                prev_state=obs,
                next_state=next_obs,
                action=action,
                reward=reward,
                terminated=terminated,
            ))

            if step % 4 == 0:
                agent.learn()

            obs = next_obs
            total_reward += reward

            if info["is_success"]:
                success = True
            if info["collision"]:
                collision = True

            if done:
                break

        agent.decay_epsilon()

        results.append({
            "episode": episode,
            "reward": total_reward,
            "success": int(success),
            "collision": int(collision),
            "steps": step + 1,
            "epsilon": agent.epsilon,
            "final_distance": info["distance_to_goal"],
        })
        if episode % 10 == 0:#cada 10 episodios mostramos por pantalla como va el entrenamiento
            clear_output(wait=True)
            print(f"Episode {episode} | dist: {info['distance_to_goal']:.2f} | reward: {total_reward:.1f} | epsilon: {agent.epsilon:.3f}")

    env.close()

    os.makedirs("results", exist_ok=True)
    df = pd.DataFrame(results)
    df.to_csv("results/dueling_dqn_results.csv", index=False)
    agent.save("results/dueling_dqn_model.pt")

    print("Entrenamiento terminado.")
    print("Resultados guardados en results/dueling_dqn_results.csv")
    print("Modelo guardado en results/dueling_dqn_model.pt")

    return agent, df


agent, df = train_dueling_dqn()
# Out:
# Training DQN: 100%|█████████▉| 1991/2000 [35:11<00:06,  1.39it/s]
# Episode 1990 | dist: 0.60 | reward: -13.8 | epsilon: 0.100
# Training DQN: 100%|██████████| 2000/2000 [35:19<00:00,  1.06s/it]
# Entrenamiento terminado.
# Resultados guardados en results/dueling_dqn_results.csv
# Modelo guardado en results/dueling_dqn_model.pt

# %%
import os
import sys
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import torch
import numpy as np
from IPython.display import display, clear_output

sys.path.append(os.path.abspath(".."))
from envs.continuous_parking_env import ContinuousParkingEnv

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model_dqn = DuelingQNetwork(n_obs=18, n_actions=7).to(device)
model_dqn.load_state_dict(torch.load("results/dueling_dqn_model.pt", map_location=device))
model_dqn.eval()

def plot_results(nombre, window=100):
    """Visualiza las métricas de entrenamiento de un algoritmo.
    nombre: clave del CSV (ej: 'dqn', 'double_dqn', 'dueling_dqn')
    """
    df = pd.read_csv(f"results/{nombre}_results.csv")

    df["reward_ma"]         = df["reward"].rolling(window).mean()
    df["success_ma"]        = df["success"].rolling(window).mean()
    df["collision_ma"]      = df["collision"].rolling(window).mean()
    df["steps_ma"]          = df["steps"].rolling(window).mean()
    df["final_distance_ma"] = df["final_distance"].rolling(window).mean()

    titulo = nombre.replace("_", " ").upper()

    metricas = [
        ("reward",         "Recompensa",              "Recompensa por episodio",    None),
        ("success",        "Tasa de éxito",           "Tasa de éxito",             (0, 1)),
        ("collision",      "Tasa de colisión",        "Colisiones",                (0, 1)),
        ("steps",          "Pasos",                   "Pasos por episodio",        None),
        ("final_distance", "Distancia final a plaza", "Distancia final al objetivo", None),
    ]

    for col, ylabel, subtitulo, ylim in metricas:
        plt.figure(figsize=(9, 4))
        if col == "reward":
            plt.plot(df["episode"], df[col], alpha=0.25, label=ylabel)
        plt.plot(df["episode"], df[f"{col}_ma"], label=f"{ylabel} media móvil {window}")
        plt.xlabel("Episodio")
        plt.ylabel(ylabel)
        plt.title(f"{titulo} - {subtitulo}")
        if ylim:
            plt.ylim(*ylim)
        plt.legend()
        plt.grid(True)
        plt.show()


def render_inline(env):
    """Renderiza el estado actual del entorno como figura inline en Jupyter."""
    fig, ax = plt.subplots(figsize=(8, 5))
    ax.set_xlim(0, env.world_width)
    ax.set_ylim(0, env.world_height)
    ax.set_aspect("equal")
    ax.set_title("Entorno Parking Simulado")

    for ox, oy, ow, oh in env.obstacles:
        ax.add_patch(patches.Rectangle((ox, oy), ow, oh, color="steelblue", alpha=0.6))

    ax.add_patch(patches.Rectangle(
        (env.parking_center[0] - 0.4, env.parking_center[1] - 0.6),
        0.8, 1.2, fill=False, edgecolor="black", linewidth=2
    ))

    for relative_angle in env.sensor_angles:
        ray_angle = env.theta + relative_angle
        d = env._cast_ray(ray_angle)
        ax.plot([env.x, env.x + d * np.cos(ray_angle)],
                [env.y, env.y + d * np.sin(ray_angle)],
                linestyle="--", linewidth=0.8, color="gray")

    ax.plot(env.x, env.y, "o", markersize=10, color="steelblue")
    ax.arrow(env.x, env.y, 0.4 * np.cos(env.theta), 0.4 * np.sin(env.theta),
             head_width=0.15, length_includes_head=True, color="black")
    ax.grid(True, alpha=0.3)

    clear_output(wait=True)
    display(fig)
    plt.close(fig)


def visualizar_agente(nombre, model, max_steps=300):
    """Ejecuta un episodio mostrando el comportamiento del agente en el parking.
    nombre: nombre del algoritmo (ej: 'DQN', 'Double DQN', 'Dueling DQN')
    model:  red neuronal cargada con pesos entrenados, en modo eval()
    """

    print(f"\n--- Episodio {i+1}/5 ---")
    
    device = next(model.parameters()).device
    env = ContinuousParkingEnv(render_mode=None)
    obs, _ = env.reset(seed=i)  # seed distinta cada vez
    
    for step in range(300):
        state_t = torch.FloatTensor(obs).unsqueeze(0).to(device)
        with torch.no_grad():
            action = int(model(state_t).argmax().item())
        obs, reward, terminated, truncated, info = env.step(action)
        render_inline(env)
        if terminated or truncated:
            break

    status = "✅ Aparcado" if info["is_success"] else "💥 Colisión" if info["collision"] else "⏱ Tiempo agotado"
    print(f"Episodio {i+1} — {step+1} pasos — {status} — distancia: {info['distance_to_goal']:.3f} m")
    env.close()

# %%
plot_results("dueling_dqn")

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model_dqn = DuelingQNetwork(n_obs=18, n_actions=7).to(device)
model_dqn.load_state_dict(torch.load("results/dueling_dqn_model.pt", map_location=device))
model_dqn.eval()

print(f"\n--- Episodio")
visualizar_agente("Double DQN", model_dqn)
# Out:
# Episodio 1 — 260 pasos — ⏱ Tiempo agotado — distancia: 0.375 m

# %% [markdown]
# ## Conclusiones del Dueling DQN
#
# El Dueling DQN mantiene el mismo algoritmo de entrenamiento que el DQN estándar e introduce una única innovación, de naturaleza puramente arquitectónica: en lugar de estimar Q(s, a) directamente, descompone la red en dos cabezas especializadas:
#
# $$Q(s, a) = V(s) + \left( A(s, a) - \frac{1}{|\mathcal{A}|} \sum_{a'} A(s, a') \right)$$
#
# donde **V(s)** es el valor intrínseco del estado y **A(s, a)** es la ventaja relativa de cada acción. La resta de la media — no del máximo — evita que la descomposición colapse y mantiene gradientes estables.
#
# Esta separación permite que la red aprenda qué estados son valiosos **sin necesidad de visitar cada par (s, a) individualmente**, lo que se traduce en una convergencia significativamente más rápida.
#
# ### Resultados destacados
#
# Los datos lo confirman de forma contundente. A los **2 000 episodios**:
#
# | Algoritmo | Tasa de éxito | Dist. media final |
# |---|---|---|
# | DQN | 0 % | 5.73 m |
# | Double DQN | 0 % | 4.52 m |
# | **Dueling DQN** | **32.2 %** | **1.80 m** |
#
# La MA50 de éxito supera el **50 % en el episodio ~1 050** — hito que los otros dos algoritmos no alcanzan en ningún momento de sus respectivos entrenamientos. En los últimos 500 episodios la tasa de éxito es del **58.8 %** con colisiones prácticamente inexistentes (0.6 %).
#
# ### Limitación práctica
#
# El entrenamiento se detuvo a los 2 000 episodios por limitaciones de tiempo de cómputo, **no por convergencia**. La tendencia en los últimos tramos muestra que la política seguía mejorando activamente. Con un entrenamiento de 5 000-6 000 episodios los resultados serían sensiblemente superiores, consolidándolo como la solución más robusta de las tres implementadas.
#
# ---
#
# ## Tabla de Hiperparámetros — Dueling DQN
#
# | Hiperparámetro | Valor | Justificación |
# |---|---|---|
# | Episodios | 2 000 | Convergencia en ep. ~700; detenido por tiempo, no por converger. Con más episodios los resultados mejorarían significativamente. |
# | Pasos máximos / episodio | 300 | Igual que los anteriores. |
# | Warmup steps | 1 000 | Reducido (vs. 5 000 en DQN/Double). La arquitectura Dueling generaliza mejor desde el principio. |
# | Factor de descuento γ | 0.95 | Ligeramente inferior al de los otros (0.99). γ = 0.99 producía inestabilidad en fases de exploración con esta arquitectura. |
# | Tasa de aprendizaje lr | 1 × 10⁻³ | Más alta que en DQN/Double (5 × 10⁻⁴). Los gradientes de la arquitectura Dueling son más informativos y permiten pasos más grandes. |
# | Tamaño de batch | 64 | Reducido (vs. 128). Más ruido en el gradiente actúa como regularización implícita en las primeras etapas. |
# | Tamaño replay buffer | 10 000 | Más pequeño (vs. 60 000). Con mejor generalización, un buffer compacto mantiene experiencias más recientes y relevantes. |
# | ε inicial | 1.0 | Igual que los anteriores. |
# | ε mínimo | 0.05 | Más bajo que DQN/Double (0.1). Con convergencia más rápida se puede reducir la exploración residual sin riesgo. |
# | ε decay | 0.995 | Más rápido que los anteriores. Con 2 000 episodios y convergencia temprana, conviene pasar antes a explotación. |
# | Frecuencia de aprendizaje | Cada 4 pasos | Igual que los anteriores. |
# | Arquitectura | 18 → 64 → 64 → {V:1, A:7} | Tronco compartido + cabeza de valor (escalar) y cabeza de ventaja (7 valores). Más eficiente que el Double DQN (128 neuronas) porque cada parámetro aporta información más específica. |
